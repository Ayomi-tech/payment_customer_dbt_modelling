# %% [markdown]
# ## Ingestion Configuration

# %%
ingestion_config = [
    {  
       "source": "crm",
        "path": "/Volumes/workspace/bronze/data_source/source_crm/customer_info.csv",
        "table": "crm_customer_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/data_source/source_crm/product_info.csv",
        "table": "crm_product_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/data_source/source_crm/sales_details.csv",
        "table": "crm_sales_details"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/data_source/source_erp/customer_details.csv",
        "table": "erp_customer_details"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/data_source/source_erp/location.csv",
        "table": "erp_location"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/data_source/source_erp/product_category.csv",
        "table": "erp_product_category"
    }
    ]

# %% [markdown]
# ## Write files into the Bronze Tables

# %%
for file in ingestion_config:

    data = (
      spark.read.option("header", "true").option("inferSchema", "true").csv(file["path"])
      )
    (
      data.write.mode("append").format("delta").saveAsTable(f"workspace.bronze.{file['table']}")
    )
